# %%
import crowdmag as cm
import geomag as gm

# %% [markdown]
# ## CrowdMag Data

# %%
pathCM = 'data/crowdmag/'
filenameCM = 'crowdmag_office 5_iPhone12,1_2021-12-19 025911.csv'

# %%
cm.PlotBCrowdMag(pathCM + filenameCM,
                 fieldtype=1,
                 start=3,end=-1)

# %% [markdown]
# ## Download Relevant GeoMag Data

# %%
gm.DownloadGeoMag(pathCM + filenameCM)
# Out:
# Download URL: https://geomag.usgs.gov/ws/data/?elements=H&endtime=2021-12-19T02:57:34.000Z&format=iaga2002&id=BRW&sampling_period=60&starttime=2021-12-17T20:14:14.000Z&type=adjusted
# Downloaded file successfully. Observatory: BRW, B-field component: H, Start date: 2021-12-17, End date: 2021-12-19.
# Geomag data file location: 'C:\Users\Judit\Documents\GitHub\NOAA_CrowdMag\magneto\data\geomag'.

# %%
pathGM = 'data/geomag/'
filenameGM = 'geomagBRWH_2021-12-17_2021-12-19.csv'

# %%
gm.PlotBGeoMag(pathCM + filenameCM,
               observatory='BRW',
               fieldtype=1,
               start=0,end=-1)
# Out:
# Download URL: https://geomag.usgs.gov/ws/data/?elements=X&endtime=2021-12-19T02:57:34.000Z&format=iaga2002&id=BRW&sampling_period=60&starttime=2021-12-17T20:14:14.000Z&type=adjusted
# Downloaded file successfully. Observatory: BRW, B-field component: X, Start date: 2021-12-17, End date: 2021-12-19.
# Geomag data file location: 'C:\Users\Judit\Documents\GitHub\NOAA_CrowdMag\magneto\data\geomag'.
# Download URL: https://geomag.usgs.gov/ws/data/?elements=Y&endtime=2021-12-19T02:57:34.000Z&format=iaga2002&id=BRW&sampling_period=60&starttime=2021-12-17T20:14:14.000Z&type=adjusted
# Downloaded file successfully. Observatory: BRW, B-field component: Y, Start date: 2021-12-17, End date: 2021-12-19.
# Geomag data file location: 'C:\Users\Judit\Documents\GitHub\NOAA_CrowdMag\magneto\data\geomag'.
# Download URL: https://geomag.usgs.gov/ws/data/?elements=Z&endtime=2021-12-19T02:57:34.000Z&format=iaga2002&id=BRW&sampling_period=60&starttime=2021-12-17T20:14:14.000Z&type=adjusted
# Downloaded file successfully. Observatory: BRW, B-field component: Z, Start date: 2021-12-17, End date: 2021-12-19.
# Geomag data file location: 'C:\Users\Judit\Documents\GitHub\NOAA_CrowdMag\magneto\data\geomag'.
# Download URL: https://geomag.usgs.gov/ws/data/?elements=H&endtime=2021-12-19T02:57:34.000Z&format=iaga2002&id=BRW&sampling_period=60&starttime=2021-12-17T20:14:14.000Z&type=adjusted
# Downloaded file successfully. Observatory: BRW, B-field component: H, Start date: 2021-12-17, End date: 2021-12-19.
# Geomag data file location: 'C:\Users\Judit\Documents\GitHub\NOAA_CrowdMag\magneto\data\geomag'.
