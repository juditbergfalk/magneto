# %%
import crowdmag as cm
import geomag as gm
import correlation as cor

# %% [markdown]
# ## CrowdMag Data

# %% [markdown]
# ### Key:
# >fieldtype = 'T'  - total magnetic field <br>
# >fieldtype = 'H'  - horizontal component of field <br>
# >fieldtype = 'X'  - x-component of magnetic field <br>
# >fieldtype = 'Y'  - y-component of magnetic field <br>
# >fieldtype = 'Z'  - z-component of magnetic field <br>

# %%
pathCM = 'data/crowdmag/'
filenameCM = 'crowdmag_office 5_iPhone12,1_2021-12-19 025911.csv'
fieldtype='Z'

# %%
cm.PlotBCrowdMag(pathCM + filenameCM,
                 fieldtype=fieldtype,
                 start=3,end=-1)
                 #start=30,end=40)

# %% [markdown]
# ## Download Relevant GeoMag Data

# %%
gm.DownloadGeoMag(pathCM + filenameCM)
# Out:
# Download URL: https://geomag.usgs.gov/ws/data/?elements=H&endtime=2021-12-19T02:57:34.000Z&format=iaga2002&id=BRW&sampling_period=60&starttime=2021-12-17T20:14:14.000Z&type=adjusted
# Downloaded file successfully. Observatory: BRW, B-field component: H, Start date: 2021-12-17, End date: 2021-12-19.
# Geomag data file location: 'C:\Users\Judit\Documents\GitHub\NOAA_CrowdMag\magneto\data\geomag'.

# %%
pathGM = 'data/geomag/'
filenameGM = 'geomagBRWH_2021-12-17_2021-12-19.csv'
observatory = 'BRW'
download = False        # download = False saves time if the file was previously downloaded

# %%
gm.PlotBGeoMag(pathCM + filenameCM,
               observatory=observatory,
               fieldtype=fieldtype,
               start=0,end=-1,
               download=download)

# %% [markdown]
# ## Plot Two Data Sets

# %%
cor.PlotOverlay2Data(pathCM + filenameCM,
                          observatory=observatory,
                          fieldtype=fieldtype,
                          start=3,end=-1,
                          download=download)

# %% [markdown]
# ## Scatter Plot and Fitting

# %%
cor.ScatterPlot(pathCM + filenameCM,
                observatory=observatory,
                fieldtype=fieldtype,
                start=3,end=-1,
                download=download)
# Out:
# Correlation coefficient of the two datasets is -0.29.
# Slope = -0.02036659541635988
# Intercept = 54877.96742679592
# Chi-squared = 4.598231039580089
# Reduced chi-squared = 0.0029121159212033496
